# %%
import requests
import time
import pandas as pd

API_KEY="AIzaSyAnRLsVqiPz-sg2cJ8qW1t9XZbL3yJ2cOw"
url="https://maps.googleapis.com/maps/api/place/textsearch/json"

cities_1=["Paris, France",
    "Lyon, France",
    "Marseille, France",
    "Nice, France",
    "Bordeaux, France",

    "Brussels, Belgium",
    "Amsterdam, Netherlands",
    "Rotterdam, Netherlands",
    "Luxembourg City, Luxembourg",

    "Rome, Italy",
    "Milan, Italy",
    "Venice, Italy",
    "Florence, Italy",
    "Naples, Italy",

    "Barcelona, Spain",
    "Madrid, Spain",
    "Seville, Spain",
    "Valencia, Spain",
    "Lisbon, Portugal",
    "Porto, Portugal"]

categories=["restaurants", "cafes", "bars", "bakeries", "coffee"]

data=[]
repid=set()

for city in cities_1:
    for i in categories:
        page=1
        token=None
        while page<=3:
            if token:
                params={"pagetoken": token, "key": API_KEY}
                time.sleep(2.2)
            else:
                params = {"query": f"{i} in {city}", "language": "en", "key": API_KEY}
            d=requests.get(url, params=params)
            r=d.json()
            status=r.get("status", "")
            if status not in ("OK","ZERO_RESULTS"):
                break
            for c in r.get("results",[]):
                id=c.get("place_id")
                if not id or id in repid:
                    continue
                repid.add(id)
                geo=c.get("geometry", {})
                loc=geo.get("location",{})
                lat=loc.get("lat")
                lng=loc.get("lng")
                row = {
                    "Айди локации": id,
                    "Название": c.get("name"),
                    "Адрес": c.get("formatted_address"),
                    "Рейтинг заведения": c.get("rating"),
                    "Количество оценок": c.get("user_ratings_total"),
                    "Ценовая категория": c.get("price_level"),
                    "Статус": c.get("business_status"),
                    "Широта": loc.get("lat"),
                    "Долгота":loc.get("lng"),
                    "Город":city,
                    "Категория":i}
                data.append(row)

            if status=="ZERO_RESULTS":
                break

            token=r.get("next_page_token")
            if not token:
                break

            page+=1
            time.sleep(0.3)

df=pd.DataFrame(data)
df.to_csv("google_places_part1.csv", index=False)
print(len(df))

# %%
import requests
import time
import pandas as pd

API_KEY="AIzaSyAnRLsVqiPz-sg2cJ8qW1t9XZbL3yJ2cOw"
url="https://maps.googleapis.com/maps/api/place/textsearch/json"

cities_2 = [
    #Центральная Европа
    "Vienna, Austria",
    "Prague, Czech Republic",
    "Budapest, Hungary",
    "Krakow, Poland",
    "Warsaw, Poland",
    "Zurich, Switzerland",
    "Geneva, Switzerland",
    "Ljubljana, Slovenia",

    #Северная Европа
    "Copenhagen, Denmark",
    "Stockholm, Sweden",
    "Oslo, Norway",
    "Helsinki, Finland",
    "Tallinn, Estonia",
    "Riga, Latvia",
    "Vilnius, Lithuania",

    #Юго-Восточная и Восточная Европа
    "Zagreb, Croatia",
    "Dubrovnik, Croatia",
    "Belgrade, Serbia",
    "Bucharest, Romania",
    "Sofia, Bulgaria"]

categories=["restaurants", "cafes", "bars", "bakeries", "coffee"]

data=[]
repid=set()

for city in cities_2:
    for i in categories:
        page=1
        token=None

        while page<=3:
            if token:
                params={"pagetoken": token, "key": API_KEY}
                time.sleep(2.2)
            else:
                params = {"query": f"{i} in {city}","language": "en","key": API_KEY}
            d=requests.get(url, params=params)
            r=d.json()
            status=r.get("status","")
            if status not in ("OK","ZERO_RESULTS"):
                break

            for c in r.get("results",[]):
                id=c.get("place_id")
                if not id or id in repid:
                    continue
                repid.add(id)

                geo=c.get("geometry", {})
                loc=geo.get("location",{})
                lat=loc.get("lat")
                lng=loc.get("lng")
                row = {"Айди локации": id,
                    "Название": c.get("name"),
                    "Адрес": c.get("formatted_address"),
                    "Рейтинг заведения": c.get("rating"),
                    "Количество оценок": c.get("user_ratings_total"),
                    "Ценовая категория": c.get("price_level"),
                    "Статус": c.get("business_status"),
                    "Широта": loc.get("lat"),
                    "Долгота": loc.get("lng"),
                    "Город (запрос)":     city,
                    "Категория (запрос)": i}
                data.append(row)

            if status=="ZERO_RESULTS":
                break
            token=r.get("next_page_token")
            if not token:
                break

            page+=1
            time.sleep(0.3)

df2=pd.DataFrame(data)
df2.to_csv("google_places_part2.csv", index=False)
print(len(df))
# Out:
# 4741

# %%
import requests
import time
import pandas as pd

API_KEY="AIzaSyAnRLsVqiPz-sg2cJ8qW1t9XZbL3yJ2cOw"
url="https://maps.googleapis.com/maps/api/place/textsearch/json"

cities_3 = [
    "London, United Kingdom",
    "Edinburgh, United Kingdom",
    "Manchester, United Kingdom",
    "Dublin, Ireland",

    "Athens, Greece",
    "Thessaloniki, Greece",
    "Nicosia, Cyprus",

    "Sarajevo, Bosnia and Herzegovina",
    "Tirana, Albania",
    "Kotor, Montenegro",
    "Skopje, North Macedonia",

    "Valletta, Malta",
    "Reykjavik, Iceland",
    "Bratislava, Slovakia"]

categories=["restaurants", "cafes", "bars", "bakeries", "coffee"]

data=[]
repid=set()

for city in cities_3:
    for i in categories:
        page=1
        token=None

        while page<=3:
            if token:
                params={"pagetoken": token, "key": API_KEY}
                time.sleep(2.2)
            else:
                params = {"query": f"{i} in {city}", "language": "en", "key": API_KEY}
            d=requests.get(url, params=params)
            r=d.json()
            status=r.get("status", "")
            if status not in ("OK", "ZERO_RESULTS"):
                break

            token=r.get("next_page_token")
            if not token:
                break

            for c in r.get("results", []):
                id=c.get("place_id")
                if not id or id in repid:
                    continue
                repid.add(id)

                geo=c.get("geometry", {})
                loc=geo.get("location",{})
                lat=loc.get("lat")
                lng=loc.get("lng")
                row = {
                    "Айди локации": id,
                    "Название": c.get("name"),
                    "Адрес": c.get("formatted_address"),
                    "Рейтинг заведения": c.get("rating"),
                    "Количество оценок": c.get("user_ratings_total"),
                    "Ценовая категория": c.get("price_level"),
                    "Статус": c.get("business_status"),
                    "Широта": loc.get("lat"),
                    "Долгота": loc.get("lng"),
                    "Город (запрос)":city,
                    "Категория (запрос)": i}
                data.append(row)

            if status=="ZERO_RESULTS":
                break

            page+=1
            time.sleep(0.3)

df3=pd.DataFrame(data)
df3.to_csv("google_places_part3.csv", index=False)
print(len(df3))
# Out:
# 4741

# %%
df1=pd.read_csv("google_places_part1.csv")
df2=pd.read_csv("google_places_part2.csv")
df3=pd.read_csv("google_places_part3.csv")
df_full=pd.concat([df1,df2,df3])
df_full=df_full.drop_duplicates(subset=["Айди локации"])
df_full.to_csv("google_places_full.csv",index=False)
